# %% [markdown]
# Loading of the libraies.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from keras.datasets import mnist

# %% [markdown]
# loading of the minst dataset

# %%
(X_train, y_train), (_, _) = mnist.load_data()
X = X_train.reshape(X_train.shape[0], -1).astype(np.float32) / 255.0 # Flatten and normalize
y = y_train
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Use of T-SNE to reduce to two diamention

# %%
print("Applying t-SNE...")
tsne = TSNE(n_components=2, random_state=42, init='random', learning_rate='auto')
X_tsne = tsne.fit_transform(X[:10000]) # Use a subset to save time
# Out:
# Applying t-SNE...

# %% [markdown]
# PLotting of the t-SNE results

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y[:10000], cmap='tab10', alpha=0.7)
plt.colorbar(scatter, ticks=range(10), label="Digit Class")
plt.title("t-SNE Visualization of MNIST")
plt.xlabel("t-SNE Component")
plt.ylabel("t-SNE Component 2&quot")
plt.show()
